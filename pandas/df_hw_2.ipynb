# %% [markdown]
# <a href="https://colab.research.google.com/github/ErbolTakhirov/Learning-notebooks/blob/main/pandas/df_hw_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
таск 6

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Task 1
#
# Создайте датафрейм из рандомно сгенеренного нампай массива целых чисел 10х10 и имен колонок:
#
#
#
# ```
# col = ['col_1', 'col_2', 'col_3', ....]
# ```

# %%
columns = ['col_' + str(i) for i in range(1, 11)]

# %%
arr = np.random.randint(1, 301, size = (10, 10))

# %%
df = pd.DataFrame(arr, columns = columns)

# %%
df
# Out:
#    col_1  col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9  col_10
# 0    169    150     49    214    278    282    270     85    199     209
# 1    253    158    276    124    118     29    173     91    198      98
# 2    210     21    299    198    199    226    282    115    159     269
# 3    186    244    297    288    296     63    164    109    103       8
# 4    224    217     44    193    247     61    165    188     96      83
# 5     41    155    285    150    143    214     66    296     27     266
# 6    150    213    238    139    216    219    178    156    183      33
# 7     61     95    266    277      1      9     72    254    177     219
# 8     11    293    184    297    260    192     42    269    105      97
# 9    192     45    137     31    272    283    110    156     40     217

# %% [markdown]
# # Task 2
#
# В колонках col_1, col_4, col_6 в трех рандомных строках значения сделайте пустыми (NaN). Постарайтесь этот процесс автоматизировать)

# %%
col = ['col_1', 'col_4', 'col_6']

# %%
index = list(np.random.choice(df.index, size = 3))

# %%
df.loc[index, col] = np.nan

# %%
df
# Out:
#    col_1  col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9  col_10
# 0  169.0    150     49  214.0    278  282.0    270     85    199     209
# 1  253.0    158    276  124.0    118   29.0    173     91    198      98
# 2    NaN     21    299    NaN    199    NaN    282    115    159     269
# 3  186.0    244    297  288.0    296   63.0    164    109    103       8
# 4  224.0    217     44  193.0    247   61.0    165    188     96      83
# 5   41.0    155    285  150.0    143  214.0     66    296     27     266
# 6    NaN    213    238    NaN    216    NaN    178    156    183      33
# 7   61.0     95    266  277.0      1    9.0     72    254    177     219
# 8   11.0    293    184  297.0    260  192.0     42    269    105      97
# 9  192.0     45    137   31.0    272  283.0    110    156     40     217

# %% [markdown]
# # Task 3
#
# Отберите из датасета 4 рандомных строки и добавте в конец фрейма. (Синтезируем дупликаты.) Обновите индексы. Чтобы в сгенеренном массиве с индексами строк не было повторов, используйте следущую нампай функцию:
#
#
#
# ```
# np.random.choice(10, 4, replace=False)
# ```
#
# Пристыковать полученные строки в конец датафрейма можно с помощью функции concat:
#
#
#
# ```
# pd.concat([df_1, df_2], axis=0)
# ```

# %%
indexes = np.random.choice(10, 4, replace=False)

# %%
df_2 = df.loc[indexes]

# %%
df_2.index = df_1.index.max() + np.arange(1, len(df_2)+ 1)

# %%
df_1 = df.copy()

# %%
df = pd.concat([df_1, df_2], axis=0)

# %% [markdown]
# # Task 4
#
# Получите нампай массив в котором будут степени заполненности по всем строкам.

# %%
df
# Out:
#     col_1  col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9  col_10
# 0   169.0    150     49  214.0    278  282.0    270     85    199     209
# 1   253.0    158    276  124.0    118   29.0    173     91    198      98
# 2     NaN     21    299    NaN    199    NaN    282    115    159     269
# 3   186.0    244    297  288.0    296   63.0    164    109    103       8
# 4   224.0    217     44  193.0    247   61.0    165    188     96      83
# 5    41.0    155    285  150.0    143  214.0     66    296     27     266
# 6     NaN    213    238    NaN    216    NaN    178    156    183      33
# 7    61.0     95    266  277.0      1    9.0     72    254    177     219
# 8    11.0    293    184  297.0    260  192.0     42    269    105      97
# 9   192.0     45    137   31.0    272  283.0    110    156     40     217
# 10  186.0    244    297  288.0    296   63.0    164    109    103       8
# 11   11.0    293    184  297.0    260  192.0     42    269    105      97
# 12  253.0    158    276  124.0    118   29.0    173     91    198      98
# 13    NaN    213    238    NaN    216    NaN    178    156    183      33

# %%
df.notnull().mean(axis = 1).values
# Out:
# array([1. , 1. , 0.7, 1. , 1. , 1. , 0.7, 1. , 1. , 1. , 1. , 1. , 1. ,
#        0.7])

# %% [markdown]
# # Task 5
#
# Удалите те строки, где количество пропусков от двух. Если один пропуск, то удаление не требуется.

# %%
df.shape[1]
# Out:
# 10

# %%
n = 2
df.dropna(thresh = df.shape[1] - n, axis = 0)
# Out:
#     col_1  col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9  col_10
# 0   169.0    150     49  214.0    278  282.0    270     85    199     209
# 1   253.0    158    276  124.0    118   29.0    173     91    198      98
# 3   186.0    244    297  288.0    296   63.0    164    109    103       8
# 4   224.0    217     44  193.0    247   61.0    165    188     96      83
# 5    41.0    155    285  150.0    143  214.0     66    296     27     266
# 7    61.0     95    266  277.0      1    9.0     72    254    177     219
# 8    11.0    293    184  297.0    260  192.0     42    269    105      97
# 9   192.0     45    137   31.0    272  283.0    110    156     40     217
# 10  186.0    244    297  288.0    296   63.0    164    109    103       8
# 11   11.0    293    184  297.0    260  192.0     42    269    105      97
# 12  253.0    158    276  124.0    118   29.0    173     91    198      98

# %%
df
# Out:
#     col_1  col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9  col_10
# 0   169.0    150     49  214.0    278  282.0    270     85    199     209
# 1   253.0    158    276  124.0    118   29.0    173     91    198      98
# 2     NaN     21    299    NaN    199    NaN    282    115    159     269
# 3   186.0    244    297  288.0    296   63.0    164    109    103       8
# 4   224.0    217     44  193.0    247   61.0    165    188     96      83
# 5    41.0    155    285  150.0    143  214.0     66    296     27     266
# 6     NaN    213    238    NaN    216    NaN    178    156    183      33
# 7    61.0     95    266  277.0      1    9.0     72    254    177     219
# 8    11.0    293    184  297.0    260  192.0     42    269    105      97
# 9   192.0     45    137   31.0    272  283.0    110    156     40     217
# 10  186.0    244    297  288.0    296   63.0    164    109    103       8
# 11   11.0    293    184  297.0    260  192.0     42    269    105      97
# 12  253.0    158    276  124.0    118   29.0    173     91    198      98
# 13    NaN    213    238    NaN    216    NaN    178    156    183      33

# %% [markdown]
# # Task 6
#
# Заполните все пропуски средними по соответствующим колонкам.

# %%
# df.fillna(df.mean(axis = 1))

# %%
df = df.apply(lambda row: row.fillna(row.mean()), axis=0)

# %%
у вас тут не правильно !

# %%
Ты заполняешь средним по строке (ось 1), а нужно по колонке (ось 0).

То есть ты заполнил строки, а не столбцы.

# %%
df = df.fillna(df.mean())

# %%
df
# Out:
#          col_1  col_2  col_3       col_4  col_5       col_6  col_7  col_8  \
# 0   169.000000    150     49  214.000000    278  282.000000    270     85
# 1   253.000000    158    276  124.000000    118   29.000000    173     91
# 2   144.272727     21    299  207.545455    199  128.818182    282    115
# 3   186.000000    244    297  288.000000    296   63.000000    164    109
# 4   224.000000    217     44  193.000000    247   61.000000    165    188
# 5    41.000000    155    285  150.000000    143  214.000000     66    296
# 6   144.272727    213    238  207.545455    216  128.818182    178    156
# 7    61.000000     95    266  277.000000      1    9.000000     72    254
# 8    11.000000    293    184  297.000000    260  192.000000     42    269
# 9   192.000000     45    137   31.000000    272  283.000000    110    156
# 10  186.000000    244    297  288.000000    296   63.000000    164    109
# 11   11.000000    293    184  297.000000    260  192.000000     42    269
# 12  253.000000    158    276  124.000000    118   29.000000    173     91
# 13  144.272727    213    238  207.545455    216  128.818182    178    156
#
#     col_9  col_10
# 0     199     209
# 1     198      98
# 2     159     269
# 3     103       8
# 4      96      83
# 5      27     266
# 6     183      33
# 7     177     219
# 8     105      97
# 9      40     217
# 10    103       8
# 11    105      97
# 12    198      98
# 13    183      33

# %% [markdown]
# # Task 7
#
# Переименуйте первую колонку в 'user_id' и все элементы приведите к виду 'ID_15'.. Дробных значений чисел быть не должно.

# %%
id = ['ID_' + str(int(i)) for i in df.user_id.values]

# %%
df = df.rename(columns = {df.columns[0]: 'user_id'})

# %%
df
# Out:
#        user_id  col_2  col_3       col_4  col_5       col_6  col_7  col_8  \
# 0   187.000000  244.0   60.0  292.000000    5.0  117.000000  117.0  144.0
# 1    47.000000  184.0   12.0  237.000000  189.0   65.000000  124.0  171.0
# 2   167.857143  246.0  237.0  167.857143   96.0  167.857143  165.0   27.0
# 3   151.857143   50.0  285.0  151.857143  151.0  151.857143  187.0  274.0
# 4   141.000000   92.0  290.0  180.000000   45.0  124.000000   95.0   23.0
# 5   220.000000  199.0   93.0  297.000000  209.0  140.000000  249.0  140.0
# 6    88.000000  282.0  250.0  234.000000   23.0  212.000000  207.0   83.0
# 7   225.000000  266.0   42.0   42.000000   72.0  256.000000  171.0   72.0
# 8   136.857143   88.0  247.0  136.857143   53.0  136.857143  213.0   67.0
# 9     3.000000  122.0  258.0  298.000000  248.0   15.000000  191.0    6.0
# 10  225.000000  266.0   42.0   42.000000   72.0  256.000000  171.0   72.0
# 11  151.857143   50.0  285.0  151.857143  151.0  151.857143  187.0  274.0
# 12    3.000000  122.0  258.0  298.000000  248.0   15.000000  191.0    6.0
# 13   88.000000  282.0  250.0  234.000000   23.0  212.000000  207.0   83.0
#
#     col_9  col_10
# 0   193.0   295.0
# 1   290.0   160.0
# 2   218.0   186.0
# 3     9.0   107.0
# 4   181.0   208.0
# 5    39.0    88.0
# 6   135.0   136.0
# 7   113.0   280.0
# 8   215.0    75.0
# 9    37.0    82.0
# 10  113.0   280.0
# 11    9.0   107.0
# 12   37.0    82.0
# 13  135.0   136.0

# %%
df['user_id'] = id

# %%
df
# Out:
#    user_id  col_2  col_3       col_4  col_5       col_6  col_7  col_8  col_9  \
# 0   ID_187  244.0   60.0  292.000000    5.0  117.000000  117.0  144.0  193.0
# 1    ID_47  184.0   12.0  237.000000  189.0   65.000000  124.0  171.0  290.0
# 2   ID_167  246.0  237.0  167.857143   96.0  167.857143  165.0   27.0  218.0
# 3   ID_151   50.0  285.0  151.857143  151.0  151.857143  187.0  274.0    9.0
# 4   ID_141   92.0  290.0  180.000000   45.0  124.000000   95.0   23.0  181.0
# 5   ID_220  199.0   93.0  297.000000  209.0  140.000000  249.0  140.0   39.0
# 6    ID_88  282.0  250.0  234.000000   23.0  212.000000  207.0   83.0  135.0
# 7   ID_225  266.0   42.0   42.000000   72.0  256.000000  171.0   72.0  113.0
# 8   ID_136   88.0  247.0  136.857143   53.0  136.857143  213.0   67.0  215.0
# 9     ID_3  122.0  258.0  298.000000  248.0   15.000000  191.0    6.0   37.0
# 10  ID_225  266.0   42.0   42.000000   72.0  256.000000  171.0   72.0  113.0
# 11  ID_151   50.0  285.0  151.857143  151.0  151.857143  187.0  274.0    9.0
# 12    ID_3  122.0  258.0  298.000000  248.0   15.000000  191.0    6.0   37.0
# 13   ID_88  282.0  250.0  234.000000   23.0  212.000000  207.0   83.0  135.0
#
#     col_10
# 0    295.0
# 1    160.0
# 2    186.0
# 3    107.0
# 4    208.0
# 5     88.0
# 6    136.0
# 7    280.0
# 8     75.0
# 9     82.0
# 10   280.0
# 11   107.0
# 12    82.0
# 13   136.0

# %% [markdown]
# # Task 8
#
# Удалите повторы по строкам. Приведите индексы в порядок при необходимости.

# %%
df.drop_duplicates()
# Out:
#   user_id  col_2  col_3       col_4  col_5       col_6  col_7  col_8  col_9  \
# 0  ID_187  244.0   60.0  292.000000    5.0  117.000000  117.0  144.0  193.0
# 1   ID_47  184.0   12.0  237.000000  189.0   65.000000  124.0  171.0  290.0
# 2  ID_167  246.0  237.0  167.857143   96.0  167.857143  165.0   27.0  218.0
# 3  ID_151   50.0  285.0  151.857143  151.0  151.857143  187.0  274.0    9.0
# 4  ID_141   92.0  290.0  180.000000   45.0  124.000000   95.0   23.0  181.0
# 5  ID_220  199.0   93.0  297.000000  209.0  140.000000  249.0  140.0   39.0
# 6   ID_88  282.0  250.0  234.000000   23.0  212.000000  207.0   83.0  135.0
# 7  ID_225  266.0   42.0   42.000000   72.0  256.000000  171.0   72.0  113.0
# 8  ID_136   88.0  247.0  136.857143   53.0  136.857143  213.0   67.0  215.0
# 9    ID_3  122.0  258.0  298.000000  248.0   15.000000  191.0    6.0   37.0
#
#    col_10
# 0   295.0
# 1   160.0
# 2   186.0
# 3   107.0
# 4   208.0
# 5    88.0
# 6   136.0
# 7   280.0
# 8    75.0
# 9    82.0
