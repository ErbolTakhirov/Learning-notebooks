# %% [markdown]
# <a href="https://colab.research.google.com/github/ErbolTakhirov/Learning-notebooks/blob/main/pandas/df_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
все верно

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Задача 1
#
# Создайте датафрейм из текущих списков со свободной индексацией и именами колонок:
#
# col_1, col_2, col_3

# %%
c_1 = [1, 2, 3, 4, 5]
c_2 = [2, 3, 4, 5, 6]
c_3 = [3, 4, 5, 6, 7]

# %%
df = pd.DataFrame([c_1, c_2, c_3], index = ['c_1', 'c_2', 'c_3'], columns = [5, 4, 3, 2, 1])

# %%
df
# Out:
#      5  4  3  2  1
# c_1  1  2  3  4  5
# c_2  2  3  4  5  6
# c_3  3  4  5  6  7

# %% [markdown]
# # Задача 2
#
# Создайте датафрейм из данного словаря.
#
# Сделайте так, чтобы лэйблы 'a', 'b', 'c' были именами колонок!

# %%
dict = {1: {'a':1, 'b':2, 'c':3}, 2: {'a':4, 'b':5, 'c':6}, 3: {'a':7, 'b':8, 'c':9}}

# %%
df = pd.DataFrame(dict).T

# %%
df
# Out:
#    a  b  c
# 1  1  2  3
# 2  4  5  6
# 3  7  8  9

# %% [markdown]
# В полученный датафрейм добавте колонку 'd' с рандомными числовыми значениями.

# %%
df['d'] = np.random.randint(1, 9, 3)

# %%
df
# Out:
#    a  b  c  d
# 1  1  2  3  6
# 2  4  5  6  3
# 3  7  8  9  4

# %% [markdown]
# # Задача 3
#
# Выведте из датасета предыдущей задачи значения строки "2" и колонок 'b', 'c' с помощью функции loc[].

# %%
df.loc[2, ['b','c']]
# Out:
# b    5
# c    6
# Name: 2, dtype: int64

# %%
df.loc[2]
# Out:
# a    4
# b    5
# c    6
# d    3
# Name: 2, dtype: int64

# %% [markdown]
# # Задача 4
#
# Выделите из датафрейма только те строки, для которых в столбце 'a' находятся четные элементы.

# %%
df.loc[df['a'] % 2 == 0]
# Out:
#    a  b  c  d
# 2  4  5  6  3

# %% [markdown]
# # Задача 5
# создайте новую колонку 'a_add_b' где будет сумма колокок 'a' и 'b'.

# %%
df['a_add_b'] = df['a'] + df['b']

# %%
df
# Out:
#    a  b  c  d  a_add_b
# 1  1  2  3  6        3
# 2  4  5  6  3        9
# 3  7  8  9  4       15

# %% [markdown]
# Проверьте четность новой колонки и ко всем нечетным прибавте 1. (фильтрация с пом loc[])

# %%
df.loc[df['a_add_b'] % 2 != 0, 'a_add_b'] + 1
# Out:
# 1     4
# 2    10
# 3    16
# Name: a_add_b, dtype: int64

# %% [markdown]
# # Задача 6
#
# Отсортируйте датафрейм по колонке 'a' в порядке убывания.
#
# Затем обновите индексы (0,1,2...) с помощью функции reset_index
#
# Удалите получившуюся колонку index

# %%
df.sort_values('a', ascending=False)
# Out:
#    a  b  c  d  a_add_b
# 3  7  8  9  4       15
# 2  4  5  6  3        9
# 1  1  2  3  6        3

# %%
df.reset_index(inplace = True)

# %%
df.drop('index', axis = 1, inplace = True)

# %%
df
# Out:
#    a  b  c  d  a_add_b
# 0  1  2  3  6        3
# 1  4  5  6  3        9
# 2  7  8  9  4       15
